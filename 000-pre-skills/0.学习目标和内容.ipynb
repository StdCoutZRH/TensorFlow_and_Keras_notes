# %% [markdown]
# 学习目标：
# * 能深入理解TensorFlow中的几个核心概念
# * 能独立完成基于TensorFlow的AI模型训练
# * 能在出现异常问题的时候合理的调试TensorFlow代码
# * 能将训练成功的模型导出成SavedModel并进一步部署到生产环境
# * 能够独立复现前沿的网络层或网络结构

# %% [markdown]
# 进阶内容:
# * Estimator
# * tf.data
# * Tensorboard
# * TensorFlow Debugger
# * TensorFlow Hub
# * TensorFlow Serving
# * Low Level API
# * Custom Layers
# * Custom Training
