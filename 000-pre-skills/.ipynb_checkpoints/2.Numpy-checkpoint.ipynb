# %% [markdown]
# ### 1.多维切片索引
# 能够做到：
# * 给定一个多维的ndarray，能熟练取出一个多维切片

# %% [markdown]
# ### 2.View && Copy
#
# * 能判断自己写的Numpy代码，得到的是View还是Copy

# %% [markdown]
# ### 3.对Numpy ndarray的轴有清晰认识
# * 当使用Numpy ndarray处理图像或者矩阵时，能正确的使用transpose

# %% [markdown]
# ### 4.对Numpy ndarray在内存上的结构有基本认识
# * 对ndarray的dtype有基本认知
# * 对ndarray的C-order与F-order有基本认知
# * 对ndarray的大小端有基本认知
