# %% [markdown]
# ### 1.基于SSH的远程访问
# * 能用一台笔记本电脑远程访问登录另一台Linux GPU服务器
# * 能随时使用笔记本电脑启动训练任务，训练过程中无需连接至服务器
# * 能熟练的让代码和文件在笔记本电脑与Linux GPU服务器之间传输

# %% [markdown]
# ### 2.Linux系统的文件系统
# * 知道什么是硬盘的挂载
# * 能熟练的使用服务器的硬盘空间，如查看当前目录属于哪块硬盘，还剩多少空间等
# * 建议学会如何在Linux系统上自建逻辑卷(LVM)，例如有4块1T硬盘，如何合成一个4T硬盘

# %% [markdown]
# ### 3.Linux系统的账户管理
# * 知道root账户与普通账户的区别
# * 能够对账户权限有基本的规划
# * 能在普通账户下，完成基于TensorFlow的AI开发

# %% [markdown]
# ### 4.Linux系统的驱动安装
# * 能够独立在Ubuntu Linux上搭建NVIDIA GPU的深度学习环境

# %% [markdown]
# ### 5.Git与GitHub
# * 有代码的版本控制意识
# * 能够掌握基本的Git使用方法
# * 能够掌握基本的GitHub使用方法
