# %% [markdown]
# ### 0.导入包配置GPU

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import tensorflow as tf 
# config GPU
# tf.debugging.set_log_device_placement(True)
phy_gpus = tf.config.experimental.list_physical_devices('GPU')
print("num of physical gpus: ",len(phy_gpus))
for gpu in phy_gpus:
   tf.config.experimental.set_memory_growth(gpu,True)
 
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import Sequential

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense,Dropout,Conv2D,MaxPooling2D,Flatten,BatchNormalization
from tensorflow.keras.optimizers import SGD
# Out:
# num of physical gpus:  1

# %% [markdown]
# ### 1.加载数据

# %%
def load_mnist_func(path):
    f = np.load(path)
    x_train, y_train = f['x_train'], f['y_train']
    x_test, y_test = f['x_test'], f['y_test']
    f.close()
    return (x_train, y_train), (x_test, y_test)


(x_train_data,y_train_data),(x_test_data,y_test_data) = load_mnist_func(path='./data/mnist/mnist.npz')
print("x_train_shape:",x_train_data.shape)
print("y_train_shape:",y_train_data.shape)
print("x_test_shape:",x_test_data.shape)
print("x_test_shape:",y_test_data.shape)
# Out:
# x_train_shape: (60000, 28, 28)
# y_train_shape: (60000,)
# x_test_shape: (10000, 28, 28)
# x_test_shape: (10000,)

# %% [markdown]
# ### 2.数据预处理

# %%
# 处理数据
#60000x28x28 ==>60000x784 并且归一化
x_train_data = x_train_data.reshape(-1,28,28,1)/255.0

x_test_data = x_test_data.reshape(-1,28,28,1)/255.0

# ==>onehot
y_train_data = to_categorical(y_train_data,num_classes=10)
y_test_data = to_categorical(y_test_data,num_classes=10)

# %% [markdown]
# ### 3.搭建CNN模型

# %%
model = Sequential()

# conv_1
model.add(Conv2D(input_shape = (28,28,1),filters = 32,kernel_size = 3,
    strides = 1,padding = 'same',activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2,strides =2,padding = 'same',))

# conv_2
model.add(Conv2D(64,3,strides=2,padding='same',activation = 'relu'))
model.add(MaxPooling2D(2,2,'same'))

# conv_3
model.add(Conv2D(128,3,strides=2,padding='same',activation = 'relu'))
model.add(MaxPooling2D(2,2,'same'))

#把第二个池化层的输出扁平化为1维
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(10,activation='softmax'))

# 定义优化器
sgd = SGD(lr=0.01)

# 定义优化器，loss function，训练过程中计算准确率
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              132096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 235,018
# Trainable params: 235,018
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.训练评估模型

# %%
model.fit(x_train_data,y_train_data,batch_size=512,epochs=100)

# 评估模型
loss,accuracy = model.evaluate(x_test_data,y_test_data)

model_path="./data/mnist/mnist_cnn.h5"
model.save(model_path,include_optimizer=True,save_format='h5')

print('test loss',loss)
print('test accuracy',accuracy)
# Out:
# Epoch 1/100
# 118/118 [==============================] - 1s 8ms/step - loss: 2.2964 - accuracy: 0.1303
# Epoch 2/100
# 118/118 [==============================] - 1s 8ms/step - loss: 2.2824 - accuracy: 0.2436
# Epoch 3/100
# 118/118 [==============================] - 1s 8ms/step - loss: 2.2595 - accuracy: 0.3162
# Epoch 4/100
# 118/118 [==============================] - 1s 8ms/step - loss: 2.2069 - accuracy: 0.3504
# Epoch 5/100
# 118/118 [==============================] - 1s 8ms/step - loss: 2.0449 - accuracy: 0.4332
# Epoch 6/100
# 118/118 [==============================] - 1s 8ms/step - loss: 1.5669 - accuracy: 0.5438
# Epoch 7/100
# 118/118 [==============================] - 1s 8ms/step - loss: 1.0828 - accuracy: 0.6560
# Epoch 8/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.8077 - accuracy: 0.7473
# Epoch 9/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.6416 - accuracy: 0.8014
# Epoch 10/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.5368 - accuracy: 0.8348
# Epoch 11/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.4609 - accuracy: 0.8599
# Epoch 12/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.4080 - accuracy: 0.8760
# Epoch 13/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.3707 - accuracy: 0.8869
# Epoch 14/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.3406 - accuracy: 0.8975
# Epoch 15/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.3158 - accuracy: 0.9040
# Epoch 16/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2947 - accuracy: 0.9111
# Epoch 17/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2758 - accuracy: 0.9167
# Epoch 18/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2592 - accuracy: 0.9209
# Epoch 19/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2454 - accuracy: 0.9259
# Epoch 20/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2337 - accuracy: 0.9286:
# Epoch 21/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2219 - accuracy: 0.9326
# Epoch 22/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2126 - accuracy: 0.9348
# Epoch 23/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.2051 - accuracy: 0.9374
# Epoch 24/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1958 - accuracy: 0.9406
# Epoch 25/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1876 - accuracy: 0.9428
# Epoch 26/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1839 - accuracy: 0.9433
# Epoch 27/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1758 - accuracy: 0.9467
# Epoch 28/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1710 - accuracy: 0.9482
# Epoch 29/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1653 - accuracy: 0.9494
# Epoch 30/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1603 - accuracy: 0.9505
# Epoch 31/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1554 - accuracy: 0.9532
# Epoch 32/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1502 - accuracy: 0.9536
# Epoch 33/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1473 - accuracy: 0.9550
# Epoch 34/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1430 - accuracy: 0.9581
# Epoch 35/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1408 - accuracy: 0.9572
# Epoch 36/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1363 - accuracy: 0.9588
# Epoch 37/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1343 - accuracy: 0.9585
# Epoch 38/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1303 - accuracy: 0.9608
# Epoch 39/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1280 - accuracy: 0.9610
# Epoch 40/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1257 - accuracy: 0.9617
# Epoch 41/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1239 - accuracy: 0.9622
# Epoch 42/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1211 - accuracy: 0.9628
# Epoch 43/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1185 - accuracy: 0.9641
# Epoch 44/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1168 - accuracy: 0.9645
# Epoch 45/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1148 - accuracy: 0.9647
# Epoch 46/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1125 - accuracy: 0.9660
# Epoch 47/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1108 - accuracy: 0.9660
# Epoch 48/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1081 - accuracy: 0.9671
# Epoch 49/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1074 - accuracy: 0.9668
# Epoch 50/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1050 - accuracy: 0.9679
# Epoch 51/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1047 - accuracy: 0.9676
# Epoch 52/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1015 - accuracy: 0.9690
# Epoch 53/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.1002 - accuracy: 0.9694
# Epoch 54/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0991 - accuracy: 0.9697
# Epoch 55/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0985 - accuracy: 0.9695
# Epoch 56/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0969 - accuracy: 0.9708
# Epoch 57/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0958 - accuracy: 0.9707
# Epoch 58/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0931 - accuracy: 0.9717
# Epoch 59/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0927 - accuracy: 0.9713
# Epoch 60/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0916 - accuracy: 0.9727
# Epoch 61/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0898 - accuracy: 0.9720
# Epoch 62/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0902 - accuracy: 0.9727
# Epoch 63/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0882 - accuracy: 0.9733
# Epoch 64/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0880 - accuracy: 0.9733
# Epoch 65/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0855 - accuracy: 0.9738
# Epoch 66/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0851 - accuracy: 0.9737
# Epoch 67/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0838 - accuracy: 0.9745
# Epoch 68/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0833 - accuracy: 0.9746
# Epoch 69/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0827 - accuracy: 0.9742
# Epoch 70/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0812 - accuracy: 0.9751
# Epoch 71/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0812 - accuracy: 0.9753
# Epoch 72/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0791 - accuracy: 0.9753
# Epoch 73/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0788 - accuracy: 0.9761
# Epoch 74/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0788 - accuracy: 0.9757
# Epoch 75/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0777 - accuracy: 0.9765
# Epoch 76/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0764 - accuracy: 0.9761
# Epoch 77/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0761 - accuracy: 0.9766
# Epoch 78/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0749 - accuracy: 0.9770
# Epoch 79/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0732 - accuracy: 0.9778
# Epoch 80/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0746 - accuracy: 0.9772
# Epoch 81/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0726 - accuracy: 0.9776
# Epoch 82/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0722 - accuracy: 0.9779
# Epoch 83/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0715 - accuracy: 0.9778
# Epoch 84/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0707 - accuracy: 0.9787
# Epoch 85/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0699 - accuracy: 0.9786
# Epoch 86/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0687 - accuracy: 0.9791
# Epoch 87/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0695 - accuracy: 0.9782
# Epoch 88/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0685 - accuracy: 0.9786
# Epoch 89/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0683 - accuracy: 0.9789
# Epoch 90/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0682 - accuracy: 0.9788
# Epoch 91/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0662 - accuracy: 0.9797
# Epoch 92/100
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0658 - accuracy: 0.9800
# Epoch 93/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0653 - accuracy: 0.9800
# Epoch 94/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0652 - accuracy: 0.9802
# Epoch 95/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0644 - accuracy: 0.9800
# Epoch 96/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0637 - accuracy: 0.9803
# Epoch 97/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0636 - accuracy: 0.9803
# Epoch 98/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0629 - accuracy: 0.9810
# Epoch 99/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0626 - accuracy: 0.9807
# Epoch 100/100
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0627 - accuracy: 0.9805
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0635 - accuracy: 0.9804
# test loss 0.06346862763166428
# test accuracy 0.980400025844574

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

model = load_model("./data/mnist/mnist_cnn.h5")

def pred(file_name,label):
    img = cv2.imread(file_name,0)
    img = cv2.resize(img,(28,28),interpolation = cv2.INTER_NEAREST)
    img = 255-img
    img = img.reshape(-1,28,28,1)/255.0
    result = model.predict(img)
    print("label is ",label,",predict result:",np.argmax(result,axis=1))
    return np.argmax(result,axis=1)

count = 0
right = 0
for img in os.listdir("./data/mnist/test_numbers/"):
    label = img[0]
    result = pred("./data/mnist/test_numbers/"+img,label)
    if str(result[0]) == label:
        right += 1
    count += 1

print("CNN accuracy：",right/count)
# Out:
# label is  0 ,predict result: [0]
# label is  1 ,predict result: [1]
# label is  2 ,predict result: [2]
# label is  3 ,predict result: [3]
# label is  4 ,predict result: [4]
# label is  5 ,predict result: [5]
# label is  6 ,predict result: [5]
# label is  7 ,predict result: [3]
# label is  8 ,predict result: [8]
# label is  9 ,predict result: [9]
# CNN accuracy： 0.8
